# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_excel("./-1546117373_-1386229357.xls")
df1.head()
# Out:
#    phos   ca  age  waist  job  home  sbp        bmi  Neck  Spine  j
# 0   3.3  8.6   57   95.0    1     1  140  27.700831     0      0  1
# 1   4.3  7.8   65   94.0    2     0  120  27.209608     0      0  0
# 2   4.4  8.5   59   90.0    1     1  140  25.918138     0      0  1
# 3   3.5  9.7   66   99.0    1     1  106  31.138985     0      0  1
# 4   3.8  9.4   64   91.0    1     0  130  28.935185     1      0  1

# %%
df2=pd.read_excel("./-1677189376_-1472644774.xls")
df2.head()
# Out:
#    phos   ca  age  waist  job  home  sbp        bmi  Neck  Spine  j
# 0   3.3  8.6   57     95    1     1  140  27.700831     0      0  1
# 1   4.3  7.8   65     94    2     0  120  27.209608     0      0  0
# 2   4.4  8.5   59     90    1     1  140  25.918138     0      0  1
# 3   3.5  9.7   66     99    1     1  106  31.138985     0      0  1
# 4   3.8  9.4   64     91    1     0  130  28.935185     1      0  1

# %%
correlation_matrix = df1.corr()

# %%
# Set the size of the plot
plt.figure(figsize=(10, 8))

# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')

# Show the plot
plt.title('Correlation Matrix')
plt.show()
